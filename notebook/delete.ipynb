# %% [markdown]
# # Eliminar documentos

# %%
from connect import db
eliminar = db.libros

# Delete One 
res = eliminar.delete_one({'titulo': '1984'})
print('Documentos eliminados:', res.deleted_count, 'libros')
# Out:
# Documentos eliminados: 1 libros
